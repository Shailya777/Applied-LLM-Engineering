# %%
from visualizer import *

message = 'In one sentence, describe the color Yellow to someone who has never been able to see'
model_name = 'gpt-4.1-mini'

predictor = TokenPredictor(model_name= model_name)
predictions = predictor.predict_tokens(message)
Graph = create_token_graph(model_name= model_name, predictions= predictions)
plt = visualize_predictions(G= Graph)
plt.show()
