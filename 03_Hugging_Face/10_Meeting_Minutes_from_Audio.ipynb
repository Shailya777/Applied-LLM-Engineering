# %% [markdown]
# # Meeting Minutes from Audio:
#
# - Data: https://drive.google.com/file/d/1N_kpSojRR5RYzupz6nqM8hMSoEF_R7pU/view?usp=sharing
#
# If you'd rather work with the original data, the HuggingFace dataset is [here](https://huggingface.co/datasets/huuuyeah/meetingbank) and the audio can be downloaded [here](https://huggingface.co/datasets/huuuyeah/MeetingBank_Audio/tree/main).
#
# The goal of this product is to use the Audio to generate meeting minutes, including actions.
#
# For this project, you can either use the Denver meeting minutes, or you can record something of your own!

# %%
# Imports:

import os
from dotenv import load_dotenv
import requests
from IPython.display import Markdown, display, update_display
from openai import OpenAI
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer, BitsAndBytesConfig
import torch

# %%
# Models:
LLAMA = 'meta-llama/Llama-3.2-3B-Instruct'
ollama = 'llama3.1:8b'
audio_filename = 'denver_extract.mp3'

# %%
# Connecting to Hugging Face:
load_dotenv(override= True)
hf_token = os.getenv('HF_TOKEN')
if hf_token and hf_token.startswith('hf_'):
    print('Hugging Face Token found!!')
    login(token= hf_token, add_to_git_credential= True)
    print('Login to Hugging Face Successful!')
else:
    print('Hugging Face Token not found!!')
# Out:
# Hugging Face Token found!!
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Login to Hugging Face Successful!

# %%
# Opening The Audio file:
audio_file = open(audio_filename, "rb")

# %% [markdown]
# ## Audio Transcription:

# %% [markdown]
# ### 1 - Using Open Source for Transcription - Hugging Face Pipelines

# %%
from transformers import pipeline

pipe = pipeline(
    task= 'automatic-speech-recognition',
    model= 'openai/whisper-medium.en',
    dtype= torch.float16,
    device= 'cuda',
    return_timestamps= True
)

result = pipe(audio_filename)
transcription = result['text']
print(transcription)
# Out:
# Loading weights:   0%|          | 0/947 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'return_timestamps'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 11
#       1 from transformers import pipeline
#       3 pipe = pipeline(
#       4     task= 'automatic-speech-recognition',
#       5     model= 'openai/whisper-medium.en',
#    (...)
#       8     return_timestamps= True
#       9 )
# ---> 11 result = pipe(audio_filename)
#      12 transcription = result['text']
#      13 print(transcription)
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:266, in AutomaticSpeechRecognitionPipeline.__call__(self, inputs, **kwargs)
#     209 def __call__(self, inputs: np.ndarray | bytes | str | dict, **kwargs: Any) -> list[dict[str, Any]]:
#     210     """
#     211     Transcribe the audio sequence(s) given as inputs to text. See the [`AutomaticSpeechRecognitionPipeline`]
#     212     documentation for more information.
#    (...)
#     264                 `"".join(chunk["text"] for chunk in output["chunks"])`.
#     265     """
# --> 266     return super().__call__(inputs, **kwargs)
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\base.py:1259, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1257     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1258 elif isinstance(self, ChunkPipeline):
# -> 1259     return next(
#    1260         iter(
#    1261             self.get_iterator(
#    1262                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1263             )
#    1264         )
#    1265     )
#    1266 else:
#    1267     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\pt_utils.py:271, in PipelinePackIterator.__next__(self)
#     268             return accumulator
#     270 while not is_last:
# --> 271     processed = self.infer(next(self.iterator), **self.params)
#     272     if self.loader_batch_size is not None:
#     273         if isinstance(processed, torch.Tensor):
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\torch\utils\data\_utils\fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\pt_utils.py:188, in PipelineChunkIterator.__next__(self)
#     185     self.subiterator = self.infer(next(self.iterator), **self.params)
#     186 try:
#     187     # Try to return next item
# --> 188     processed = next(self.subiterator)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)
#     194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#     196     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:374, in AutomaticSpeechRecognitionPipeline.preprocess(self, inputs, chunk_length_s, stride_length_s)
#     371             inputs = f.read()
#     373 if isinstance(inputs, bytes):
# --> 374     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#     376 stride = None
#     377 extra = {}
#
# File ~\anaconda3\envs\applied_llm_engineering\lib\site-packages\transformers\pipelines\audio_utils.py:40, in ffmpeg_read(bpayload, sampling_rate)
#      38 audio = np.frombuffer(out_bytes, np.float32)
#      39 if audio.shape[0] == 0:
# ---> 40     raise ValueError(
#      41         "Soundfile is either not in the correct format or is malformed. Ensure that the soundfile has "
#      42         "a valid audio file extension (e.g. wav, flac or mp3) and is not corrupted. If reading from a remote "
#      43         "URL, ensure that the URL is the full address to **download** the audio file."
#      44     )
#      45 return audio
#
# ValueError: Soundfile is either not in the correct format or is malformed. Ensure that the soundfile has a valid audio file extension (e.g. wav, flac or mp3) and is not corrupted. If reading from a remote URL, ensure that the URL is the full address to **download** the audio file.
